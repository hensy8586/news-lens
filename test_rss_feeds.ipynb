# %%
from src.rss_utils import fetch_rss_articles, fetch_article_fulltext


bbc_world_feed = "http://feeds.bbci.co.uk/news/rss.xml"

bbc_world_articles = fetch_rss_articles(
    feed_url=bbc_world_feed,
    source_outlet="BBC News",
    region="Europe",   # or "World" depending on how you want to tag
    topic="world",
    language="en",
)

print(f"Fetched {len(bbc_world_articles)} BBC world articles")
print(bbc_world_articles[0]["title"], "→", bbc_world_articles[0]["link"])
# Out:
# Fetched 31 BBC world articles
# Sir Tom Stoppard, playwright famed for his wit and depth, dies at 88 → https://www.bbc.com/news/articles/c74xe49q7vlo?at_medium=RSS&at_campaign=rss

# %%
for i, article in enumerate(bbc_world_articles, start=1):
    title = article.get("title")
    # source = article.get("source", {}).get("name")
    published_at = article.get("published_at").isoformat()
    url = article.get("link")

    print(f"{i}. {title}")
    # print(f"   Source: {source}")
    print(f"   Published: {published_at}")
    print(f"   URL: {url}\n")
# Out:
# 1. Sir Tom Stoppard, playwright famed for his wit and depth, dies at 88
#    Published: 2025-11-29T21:13:04+00:00
#    URL: https://www.bbc.com/news/articles/c74xe49q7vlo?at_medium=RSS&at_campaign=rss
#
# 2. Venezuela calls Trump airspace closure warning 'colonialist threat'
#    Published: 2025-11-29T20:11:04+00:00
#    URL: https://www.bbc.com/news/articles/c741mpdyw9no?at_medium=RSS&at_campaign=rss
#
# 3. Budget 2025: What's the best and worst that could happen for Labour?
#    Published: 2025-11-29T15:14:47+00:00
#    URL: https://www.bbc.com/news/articles/cqlk5gd3kv9o?at_medium=RSS&at_campaign=rss
#
# 4. Fall of Zelensky's top aide - reboot for Kyiv or costly shake-up?
#    Published: 2025-11-29T11:29:35+00:00
#    URL: https://www.bbc.com/news/articles/cz0nljm4y74o?at_medium=RSS&at_campaign=rss
#
# 5. Sultana claims new Corbyn party carrying out 'witch hunt' against activists
#    Published: 2025-11-29T16:36:40+00:00
# ...

# %%
for i, article in enumerate(bbc_world_articles, start=1):
    title = article.get("title")
    # source = article.get("source", {}).get("name")
    published_at = article.get("published_at").isoformat()
    url = article.get("link")

    print(f"{i}. {title}")
    # print(f"   Source: {source}")
    print(f"   Published: {published_at}")
    print(f"   URL: {url}\n")
# Out:
# 1. Venezuela calls Trump airspace closure warning 'colonialist threat'
#    Published: 2025-11-29T20:11:04+00:00
#    URL: https://www.bbc.com/news/articles/c741mpdyw9no?at_medium=RSS&at_campaign=rss
#
# 2. Flooding in southern Asia leaves 600 dead
#    Published: 2025-11-29T17:33:40+00:00
#    URL: https://www.bbc.com/news/articles/c5y9ejley9do?at_medium=RSS&at_campaign=rss
#
# 3. Fall of Zelensky's top aide - reboot for Kyiv or costly shake-up?
#    Published: 2025-11-29T11:29:35+00:00
#    URL: https://www.bbc.com/news/articles/cz0nljm4y74o?at_medium=RSS&at_campaign=rss
#
# 4. Pope Leo visits Istanbul's Blue Mosque
#    Published: 2025-11-29T15:37:57+00:00
#    URL: https://www.bbc.com/news/articles/c4gp917zr8no?at_medium=RSS&at_campaign=rss
#
# 5. Australian prime minister becomes first to wed in office
#    Published: 2025-11-29T11:02:47+00:00
#    URL: https://www.bbc.com/news/articles/ce865kpdzz8o?at_medium=RSS&at_campaign=rss
#
# ...

# %%
from src.rss_utils import fetch_article_fulltext

for article in bbc_world_articles:
    article["content_text"] = fetch_article_fulltext(article["link"])

# %%
pprint(bbc_world_articles)
# Out:
# [{'content_html': 'US President Donald Trump said the airspace around '
#                   'Venezuela should be considered closed "in its entirety".',
#   'content_text': "Venezuela calls Trump airspace closure warning 'colonialist "
#                   "threat'\n"
#                   'Venezuela has accused US President Donald Trump of making a '
#                   '"colonialist threat" after he said the airspace around the '
#                   'country should be considered closed.\n'
#                   "The country's foreign ministry called Trump's comments "
#                   '"another extravagant, illegal and unjustified aggression '
#                   'against the Venezuelan people".\n'
#                   'The US does not legally have the authority to close another '
#                   "country's airspace, but Trump's online post could lead to "
#                   'travel uncertainty and deter airlines from operating '
#                   'there.\n'
# ...

# %%
print(bbc_world_articles[0]["content_text"])
# Out:
# Venezuela calls Trump airspace closure warning 'colonialist threat'
# Venezuela has accused US President Donald Trump of making a "colonialist threat" after he said the airspace around the country should be considered closed.
# The country's foreign ministry called Trump's comments "another extravagant, illegal and unjustified aggression against the Venezuelan people".
# The US does not legally have the authority to close another country's airspace, but Trump's online post could lead to travel uncertainty and deter airlines from operating there.
# The US has been building its military presence in the Caribbean, which officials say is to combat drug smuggling. Venezuela's President Nicolás Maduro has dismissed US claims of drug trafficking as an attempt to oust him.
# In a post on Truth Social, Trump wrote: "To all Airlines, Pilots, Drug Dealers, and Human Traffickers, please consider THE AIRSPACE ABOVE AND SURROUNDING VENEZUELA TO BE CLOSED IN ITS ENTIRETY."
# ...

# %%
from src.rss_utils import fetch_rss_articles, fetch_article_fulltext

feed = "https://feeds.npr.org/1001/rss.xml"

articles = fetch_rss_articles(
    feed_url=feed,
    source_outlet="NPR News",
    region="us",
    topic="world",
    language="en",
)

print(f"Fetched {len(articles)} articles")
print(articles[0]["title"], "→", articles[0]["link"])
# Out:
# Fetched 10 articles
# More cities are seeing PFAS pollution in drinking water. Here's what Louisville found → https://www.npr.org/sections/shots-health-news/2025/11/30/nx-s1-5604679/drinking-water-pfas-genx-pollution-louisville-epa-chemours

# %%
from pprint import pprint

pprint(articles)
# Out:
# [{'content_html': '<img alt="The George Rogers Clark Memorial bridge crosses '
#                   'the Ohio River to Louisville, Kentucky." '
#                   'src="https://npr.brightspotcdn.com/dims3/default/strip/false/crop/5200x2600+0+0/resize/5200x2600!/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Fa1%2Fba%2Fb2ab03e1441fa2e4c32928fa94f0%2Fgettyimages-1558568819.jpg" '
#                   '/><p>Workers at the drinking water plant in Louisville, Ky. '
#                   "saw a sudden spike in the level of a 'forever chemical.' "
#                   'They traced it up the Ohio River to a factory embroiled in '
#                   'a pollution lawsuit.\xa0</p><p>(Image credit: Visions of '
#                   'America/Joseph Sohm)</p><img '
#                   'src="https://media.npr.org/include/images/tracking/npr-rss-pixel.png?story=nx-s1-5604679" '
#                   '/>',
#   'id': '138e1dec-0d9e-402a-2e6f-c8cc0b5ecb2d',
#   'language': 'en',
# ...

# %%
for i, article in enumerate(articles, start=1):
    title = article.get("title")
    # source = article.get("source", {}).get("name")
    published_at = article.get("published_at")
    url = article.get("link")

    print(f"{i}. {title}")
    # print(f"   Source: {source}")
    print(f"   Published: {published_at}")
    print(f"   URL: {url}\n")
# Out:
# 1. More cities are seeing PFAS pollution in drinking water. Here's what Louisville found
#    Published: 2025-11-30T09:00:00-05:00
#    URL: https://www.npr.org/sections/shots-health-news/2025/11/30/nx-s1-5604679/drinking-water-pfas-genx-pollution-louisville-epa-chemours
#
# 2. During the war in Gaza, Israel drastically changed the map of the West Bank
#    Published: 2025-11-30T08:00:25-05:00
#    URL: https://www.npr.org/2025/11/30/nx-s1-5594832/during-the-war-in-gaza-israel-drastically-changed-the-map-of-the-west-bank
#
# 3. Netanyahu submits request for a pardon during his ongoing corruption trial
#    Published: 2025-11-30T06:27:50-05:00
#    URL: https://www.npr.org/2025/11/30/nx-s1-5625482/netanyahu-request-pardon-corruption-trial
#
# 4. Rubio and Witkoff are meeting with Ukraine's negotiators in Florida as Trump pushes to broker a deal
#    Published: 2025-11-30T06:00:48-05:00
# ...

# %%
from pprint import pprint

pprint(articles)
# Out:
# [{'content_html': '<img alt="The George Rogers Clark Memorial bridge crosses '
#                   'the Ohio River to Louisville, Kentucky." '
#                   'src="https://npr.brightspotcdn.com/dims3/default/strip/false/crop/5200x2600+0+0/resize/5200x2600!/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Fa1%2Fba%2Fb2ab03e1441fa2e4c32928fa94f0%2Fgettyimages-1558568819.jpg" '
#                   '/><p>Workers at the drinking water plant in Louisville, Ky. '
#                   "saw a sudden spike in the level of a 'forever chemical.' "
#                   'They traced it up the Ohio River to a factory embroiled in '
#                   'a pollution lawsuit.\xa0</p><p>(Image credit: Visions of '
#                   'America/Joseph Sohm)</p><img '
#                   'src="https://media.npr.org/include/images/tracking/npr-rss-pixel.png?story=nx-s1-5604679" '
#                   '/>',
#   'id': '138e1dec-0d9e-402a-2e6f-c8cc0b5ecb2d',
#   'language': 'en',
# ...

# %%
from src.rss_utils import extract_headline_image

out = extract_headline_image(articles[0]["link"])
out
# Out:
# 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/4622x2600+289+0/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Fa1%2Fba%2Fb2ab03e1441fa2e4c32928fa94f0%2Fgettyimages-1558568819.jpg'

# %%
for article in articles:
    print(f"===> Fetching article: {article['title']} ...")
    text = fetch_article_fulltext(article["link"], debug=True)
    if text:
        article["content_text"] = text
    else:
        # Optionally keep track of failures
        article["content_text"] = None
        # or log:
        print(f"Skipping article (failed to fetch): {article['link']}")
# Out:
# ===> Fetching article: Northwestern settles with Trump administration in $75M deal to regain federal funding ...
# ===> Fetching article: FDA to raise hurdles for vaccines, faulting COVID shots for 10 kids' deaths ...
# ===> Fetching article: A major winter storm disrupts travel as millions head home after Thanksgiving ...
# ===> Fetching article: Acclaimed playwright Tom Stoppard dies at 88 ...
# ===> Fetching article: These Zika mothers went to battle — and their cry was heard ...
# ===> Fetching article: Opinion: My kind of holiday song ...
# ===> Fetching article: Pope's visit to Lebanon sparks hope but also frustration ...
# ===> Fetching article: As the 2025 Atlantic hurricane season ends, the future of forecasting is AI ...
# ===> Fetching article: Where things stand with the National Guard shooting in D.C. ...
# ===> Fetching article: They need a ventilator to stay alive. Getting one can be a nightmare ...

# %%
print(articles[1]["content_text"])
# Out:
# FDA to raise hurdles for vaccines, faulting COVID shots for 10 kids' deaths
# The Food and Drug Administration intends to get tougher on vaccine approvals, as top officials raised concerns about the risk of COVID vaccines for children.
# Speaking on Fox News Saturday morning, FDA Commissioner Marty Makary said the agency would no longer "rubber-stamp new products that don't work," claiming it made a "mockery of science."
# Makary's comments came the day after FDA's top vaccine regulator, Dr. Vinay Prasad, told his team the agency would change its annual flu vaccine framework, update vaccine labels to be "honest," and make other changes to how it reviews vaccines, according to contents of an internal email reviewed by NPR and reported on first by a PBS News Hour correspondent and later by The Washington Post.
# ...

# %%
from src.rss_sources import RSS_FEEDS
from src.rss_utils import fetch_rss_articles, fetch_article_fulltext, extract_headline_image


all_items = []
for feed_dict in RSS_FEEDS.values():
    feed_articles = fetch_rss_articles(
        feed_url=feed_dict["feed_url"],
        source_outlet=feed_dict["sub_source"],
        region=feed_dict["source_region"],
        topic=feed_dict["topic_region"],
        language=feed_dict["language"]
    )
    for article in feed_articles:
        article["content_text"] = fetch_article_fulltext(article["link"])
        article["image_url"] = extract_headline_image(article["link"])

    all_items.extend(feed_articles)

# %%
for article in all_items:
    print(article["image_url"])
# Out:
# https://ichef.bbci.co.uk/news/1024/branded_news/37da/live/4fc00290-ce29-11f0-be98-75d864f0578d.jpg
# https://ichef.bbci.co.uk/news/1024/branded_news/9b9b/live/5b139420-cde5-11f0-a750-a3ce41dc0968.jpg
# https://ichef.bbci.co.uk/news/1024/branded_news/882a/live/2e266e70-cde9-11f0-a750-a3ce41dc0968.jpg
# https://ichef.bbci.co.uk/news/1024/branded_news/63c8/live/ec2e8510-ce07-11f0-8c06-f5d460985095.jpg
# https://ichef.bbci.co.uk/news/1024/branded_news/60af/live/f75c3d20-cdd9-11f0-84e3-8b388d01c57d.jpg
# https://ichef.bbci.co.uk/news/1024/branded_news/f14c/live/e94afe40-ce35-11f0-b0ac-d13c1508eb1d.jpg
# https://ichef.bbci.co.uk/news/1024/branded_news/f946/live/2a7a0610-cdda-11f0-84e3-8b388d01c57d.png
# https://ichef.bbci.co.uk/news/1024/branded_news/4f37/live/0d5b8c70-cddf-11f0-a892-01d657345866.jpg
# https://ichef.bbci.co.uk/news/1024/branded_news/1e92/live/9d0e5320-ce07-11f0-b581-8bb45e928046.jpg
# ...
