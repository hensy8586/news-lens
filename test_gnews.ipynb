# %%
import os
from dotenv import load_dotenv
import requests
from datetime import datetime, timezone

load_dotenv()
GNEWS_API_KEY = os.environ.get("GNEWS_API_KEY")  # or hardcode for testing

BASE_URL = "https://gnews.io/api/v4/top-headlines"

params = {
    "token": GNEWS_API_KEY,
    "lang": "en",
    "country": "us",
    "topic": "nation",
    "q": "immigration OR ICE",
    "max": 10,
}

resp = requests.get(BASE_URL, params=params)
resp.raise_for_status()
data = resp.json()

print(f"Fetched {len(data.get('articles', []))} articles at {datetime.now(timezone.utc)}Z\n")

for i, article in enumerate(data.get("articles", []), start=1):
    title = article.get("title")
    source = article.get("source", {}).get("name")
    published_at = article.get("publishedAt")
    url = article.get("url")

    print(f"{i}. {title}")
    print(f"   Source: {source}")
    print(f"   Published: {published_at}")
    print(f"   URL: {url}\n")
# Out:
# Fetched 10 articles at 2025-11-29 20:37:09.697593+00:00Z
#
# 1. US halts all asylum decisions after National Guard shooting in DC
#    Source: AP News
#    Published: 2025-11-29T04:56:00Z
#    URL: https://apnews.com/article/national-guard-shooting-suspect-585e36855d1dddd3e801708987c776c0
#
# 2. Trump Pauses Domestic Applications for Asylum
#    Source: The New York Times
#    Published: 2025-11-29T02:49:48Z
#    URL: https://www.nytimes.com/2025/11/28/us/politics/trump-affirmative-asylum.html
#
# 3. Babson College student detained while flying out of Logan Airport
#    Source: NBC Boston
#    Published: 2025-11-29T02:08:26Z
#    URL: https://www.nbcboston.com/news/local/college-freshman-deported-flying-home-from-boston-for-thanksgiving-despite-court-order/3852170/
#
# 4. ICE deports Austin college student despite judge's stay, lawyer says
#    Source: Austin American-Statesman
#    Published: 2025-11-28T22:53:47Z
#    URL: https://www.statesman.com/news/local/article/ice-deports-austin-student-honduras-21212682.php
#
# 5. Trump administration announces pause on asylum decisions after National Guardsmen shooting
#    Source: ABC News
#    Published: 2025-11-28T20:47:52Z
#    URL: https://abcnews.go.com/Politics/trump-permanently-pause-migration-countries-after-national-guard/story?id=127942078
#
# 6. Snow emergencies declared across southern Wisconsin for over the weekend
#    Source: WMTV 15 NEWS
#    Published: 2025-11-28T20:37:00Z
#    URL: https://www.wmtv15news.com/2025/11/28/snow-emergencies-declared-across-southern-wisconsin/
#
# 7. Trump’s Response to Shooting Shows Intensified Anti-Migrant Stance
#    Source: The New York Times
#    Published: 2025-11-28T18:39:25Z
#    URL: https://www.nytimes.com/2025/11/28/us/politics/trumps-response-to-shooting-shows-intensified-anti-migrant-stance.html
#
# 8. Trump targets Gov. Walz with slur, attacks Rep. Omar and Minnesota's Somali community
#    Source: CBS News
#    Published: 2025-11-28T16:07:00Z
#    URL: https://www.cbsnews.com/minnesota/news/donald-trump-tim-walz-slur-attacks-ilhan-omar-somali-community/
#
# 9. Trump says he will ‘permanently pause’ migration from ‘third world countries’ after national guard shooting
#    Source: The Guardian
#    Published: 2025-11-28T15:49:00Z
#    URL: https://www.theguardian.com/us-news/2025/nov/28/trump-says-he-will-permanently-pause-migration-from-third-world-countries-after-national-guard-shooting
#
# 10. Karoline Leavitt’s Relative Detained by ICE Gets Bittersweet Update
#    Source: The Daily Beast
#    Published: 2025-11-28T15:18:00Z
#    URL: https://www.thedailybeast.com/white-house-spokeswoman-karoline-leavitts-brazil-relative-detained-by-dhs-ice-shares-bittersweet-update/

# %%
import pickle

with open("gnews_example_data.pkl", "wb") as f:
    pickle.dump(data, f)

# %%
from pprint import pprint
pprint(data)
# Out:
# {'articles': [{'content': 'WASHINGTON (AP) — Charges against the man accused '
#                           'of shooting two National Guard members have been '
#                           'upgraded to first-degree murder after one of the '
#                           'soldiers died, the U.S. attorney for the District '
#                           'of Columbia announced Friday, while investigators '
#                           'co... [6610 chars]',
#                'description': 'The charges against the man who authorities say '
#                               'shot two National Guard members have been '
#                               'upgraded to first-degree murder after one of '
#                               'the soldiers died.',
#                'id': '87dfa2884de1fecf5c4c2574aea22f13',
#                'image': 'https://dims.apnews.com/dims4/default/a9e36c9/2147483647/strip/true/crop/4049x2278+0+211/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2Fcf%2F00%2Fab35e3b2598c9179843c26f474a1%2F0fdf7ad420644cc7a641640222ebaa1d',
#                'lang': 'en',
#                'publishedAt': '2025-11-29T04:56:00Z',
#                'source': {'id': 'b356d47a35dfffa723fc8131b36c3ed1',
#                           'name': 'AP News',
#                           'url': 'https://apnews.com'},
#                'title': 'US halts all asylum decisions after National Guard '
#                         'shooting in DC',
#                'url': 'https://apnews.com/article/national-guard-shooting-suspect-585e36855d1dddd3e801708987c776c0'},
#               {'content': 'The Trump administration paused asylum applications '
#                           'filed by migrants inside the United States, the '
#                           'latest change to come out of the government’s '
#                           'review of the immigration system in the wake of a '
#                           'shooting of two National Guard members.\n'
#                           'The pause affe... [2127 chars]',
#                'description': 'It was the latest restrictive change to the '
#                               'immigration system after this week’s shooting '
#                               'of two National Guard members.',
#                'id': '60c5ec4b019ebe97330f06a793f60e21',
#                'image': 'https://static01.nyt.com/images/2025/11/28/multimedia/28dc-asylum-zqjp/28dc-asylum-zqjp-facebookJumbo.jpg',
#                'lang': 'en',
#                'publishedAt': '2025-11-29T02:49:48Z',
#                'source': {'id': '2f580dc49292a1caf59cd86dd3c9e60b',
#                           'name': 'The New York Times',
#                           'url': 'https://www.nytimes.com'},
#                'title': 'Trump Pauses Domestic Applications for Asylum',
#                'url': 'https://www.nytimes.com/2025/11/28/us/politics/trump-affirmative-asylum.html'},
#               {'content': 'A college freshman trying to fly from Boston to '
#                           'Texas to surprise her family for Thanksgiving was '
#                           'instead deported to Honduras in violation of a '
#                           'court order, according to her attorney.\n'
#                           'Any Lucia Lopez Belloza, 19, had already passed '
#                           'through security ... [1426 chars]',
#                'description': 'The Babson College student was detained by '
#                               'immigration officials and within two days, sent '
#                               'to Texas and then Honduras, the country she '
#                               'left at age 7.',
#                'id': 'd7b9f46fb3b762391974bd01bb5c3fe4',
#                'image': 'https://media.nbcboston.com/2025/11/Any-Lucia-Lopez-Belloza.jpg?quality=85&strip=all&resize=1200%2C675',
#                'lang': 'en',
#                'publishedAt': '2025-11-29T02:08:26Z',
#                'source': {'id': 'e1adb534a014ec3cf3bb5c5005960e8f',
#                           'name': 'NBC Boston',
#                           'url': 'https://www.nbcboston.com'},
#                'title': 'Babson College student detained while flying out of '
#                         'Logan Airport',
#                'url': 'https://www.nbcboston.com/news/local/college-freshman-deported-flying-home-from-boston-for-thanksgiving-despite-court-order/3852170/'},
#               {'content': 'Francis thought the phone call was an extortion at '
#                           'first — or, at the least, a sick prank. But as his '
#                           'daughter’s crying voice on the other side of the '
#                           'line continued, Francis realized it was all much '
#                           'worse.\n'
#                           'On the morning of Nov. 20, Francis’ 19-year... '
#                           '[5840 chars]',
#                'description': 'Arrested by ICE at Boston’s airport, the '
#                               '19-year-old Austin-area college student was '
#                               'deported to Honduras despite a federal stay, '
#                               'lawyer says.',
#                'id': '3a97907a9861f74e73c673779c05f236',
#                'image': 'https://s.hdnux.com/photos/01/55/31/04/28676392/5/rawImage.jpg',
#                'lang': 'en',
#                'publishedAt': '2025-11-28T22:53:47Z',
#                'source': {'id': '2baebf2efec2c61d01912c4ca7a8a5de',
#                           'name': 'Austin American-Statesman',
#                           'url': 'https://www.statesman.com'},
#                'title': "ICE deports Austin college student despite judge's "
#                         'stay, lawyer says',
#                'url': 'https://www.statesman.com/news/local/article/ice-deports-austin-student-honduras-21212682.php'},
#               {'content': 'The Trump administration announced on Friday that '
#                           'it is pausing all asylum decisions following the '
#                           'shooting of two National Guard members in '
#                           'Washington, D.C., earlier this week.\n'
#                           'U.S. Citizenship and Immigration Services Director '
#                           'Joseph Edlow said all... [2828 chars]',
#                'description': 'The Trump administration announced it is '
#                               'pausing all asylum decisions, not just for '
#                               'applicants hailing from Afghanistan, in the '
#                               'wake of the National Guardsmen shooting.',
#                'id': 'c04947ee247f47f93d5db1af26e26c5b',
#                'image': 'https://i.abcnewsfe.com/a/4f50c373-5942-4c4b-ab19-7fa0083b7b87/donald-trump-10-abc-gmh-251126_1764210667275_hpMain_16x9.jpg?w=1600',
#                'lang': 'en',
#                'publishedAt': '2025-11-28T20:47:52Z',
#                'source': {'id': '5ca536331c246cd7f693cdb2cceaff8c',
#                           'name': 'ABC News',
#                           'url': 'https://abcnews.go.com'},
#                'title': 'Trump administration announces pause on asylum '
#                         'decisions after National Guardsmen shooting',
#                'url': 'https://abcnews.go.com/Politics/trump-permanently-pause-migration-countries-after-national-guard/story?id=127942078'},
#               {'content': 'MADISON, Wis. (WMTV) - Multiple municipalities in '
#                           'southern Wisconsin have declared snow emergencies '
#                           'for over the weekend.\n'
#                           'City of Beloit\n'
#                           'The City of Beloit has declared a winter weather '
#                           'emergency beginning at afternoon Saturday, Nov. 29 '
#                           'to noon Sunda... [7584 chars]',
#                'description': 'Multiple municipalities in southern Wisconsin '
#                               'have declared snow emergencies over the '
#                               'weekend.',
#                'id': 'ecd28574735734f4dc7d7cec92c520c4',
#                'image': 'https://gray-wmtv-prod.gtv-cdn.com/resizer/v2/G5KZNWGTZFAFDDCXJLUQXOKPCY.jpg?auth=f73abad1cfee81ab0491684bdec39edd0ad3a45d9a012e4db8af4052dc99770f&width=1200&height=600&smart=true',
#                'lang': 'en',
#                'publishedAt': '2025-11-28T20:37:00Z',
#                'source': {'id': 'a9ada5b6f496a7b9e068707c5c1f26ef',
#                           'name': 'WMTV 15 NEWS',
#                           'url': 'https://www.wmtv15news.com'},
#                'title': 'Snow emergencies declared across southern Wisconsin '
#                         'for over the weekend',
#                'url': 'https://www.wmtv15news.com/2025/11/28/snow-emergencies-declared-across-southern-wisconsin/'},
#               {'content': 'The shooting of two National Guard members by a '
#                           'gunman identified by the authorities as an Afghan '
#                           'national has set off an especially intense level of '
#                           'fury in President Trump and a new push to step up '
#                           'his anti-immigration policies.\n'
#                           'In a series of stat... [1478 chars]',
#                'description': 'The president is furiously demanding limits on '
#                               'migration and attacking ethnic groups as he '
#                               'steps up his efforts to equate immigration with '
#                               'crime and economic distress.',
#                'id': 'e66c8b34894973883e4047077cd098a7',
#                'image': 'https://static01.nyt.com/images/2025/11/28/multimedia/28dc-trump-mzgp/28dc-trump-mzgp-facebookJumbo.jpg',
#                'lang': 'en',
#                'publishedAt': '2025-11-28T18:39:25Z',
#                'source': {'id': '2f580dc49292a1caf59cd86dd3c9e60b',
#                           'name': 'The New York Times',
#                           'url': 'https://www.nytimes.com'},
#                'title': 'Trump’s Response to Shooting Shows Intensified '
#                         'Anti-Migrant Stance',
#                'url': 'https://www.nytimes.com/2025/11/28/us/politics/trumps-response-to-shooting-shows-intensified-anti-migrant-stance.html'},
#               {'content': 'In an invective posted to the Truth Social platform '
#                           'on Thanksgiving, President Trump used a slur for '
#                           'people with intellectual disabilities to describe '
#                           'Minnesota Gov. Tim Walz.\n'
#                           'Mr. Trump also used racially and religiously '
#                           'prejudiced language against R... [1542 chars]',
#                'description': 'In an invective posted to the Truth Social '
#                               'platform on Thanksgiving, President Trump used '
#                               'a slur for people with intellectual '
#                               'disabilities to describe Minnesota Gov. Tim '
#                               'Walz.',
#                'id': '4000168dff4c58a0ffa292f4a76fc853',
#                'image': 'https://assets3.cbsnewsstatic.com/hub/i/r/2025/11/28/1bf88988-140d-4902-a035-81ddd7a35993/thumbnail/1200x630/c203052d3391d9bd5dc9d116a7a9237f/gettyimages-2248198759.jpg',
#                'lang': 'en',
#                'publishedAt': '2025-11-28T16:07:00Z',
#                'source': {'id': 'f2f2ed82d991515dcc85d86a1374a9ae',
#                           'name': 'CBS News',
#                           'url': 'https://www.cbsnews.com'},
#                'title': 'Trump targets Gov. Walz with slur, attacks Rep. Omar '
#                         "and Minnesota's Somali community",
#                'url': 'https://www.cbsnews.com/minnesota/news/donald-trump-tim-walz-slur-attacks-ilhan-omar-somali-community/'},
#               {'content': 'Donald Trump has said he will “permanently pause '
#                           'migration from all third world countries,” a day '
#                           'after two national guard members were shot in '
#                           'Washington DC in an attack that has become a '
#                           'political flashpoint in the president’s ongoing '
#                           'crackdown on ... [5011 chars]',
#                'description': 'In a social media post sent late on '
#                               'Thanksgiving, US president said he would ‘end '
#                               'all federal benefits and subsidies to '
#                               'noncitizens’ following Washington DC shooting',
#                'id': 'be5b7e5c2dbdbd75f88c3d3d5762b19e',
#                'image': 'https://i.guim.co.uk/img/media/45102e284ae426d6cdf081729affe729e777549f/201_0_2008_1606/master/2008.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&precrop=40:21,offset-x50,offset-y0&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=f01608f3ba8c9cccfd8255594ca4149c',
#                'lang': 'en',
#                'publishedAt': '2025-11-28T15:49:00Z',
#                'source': {'id': '558a003a7a0164e924408edec7e99f99',
#                           'name': 'The Guardian',
#                           'url': 'https://www.theguardian.com'},
#                'title': 'Trump says he will ‘permanently pause’ migration from '
#                         '‘third world countries’ after national guard shooting',
#                'url': 'https://www.theguardian.com/us-news/2025/nov/28/trump-says-he-will-permanently-pause-migration-from-third-world-countries-after-national-guard-shooting'},
#               {'content': 'An appeal to help the relative of Karoline Leavitt '
#                           'fight her detention by ICE has hit its '
#                           'legal-defense goal—but she remained in immigration '
#                           'detention over Thanksgiving.\n'
#                           'Bruna Ferreira, 33, the mother of the White House '
#                           'press secretary’s nephew, was ... [1636 chars]',
#                'description': 'GoFundMe tops its target, but Bruna Ferreira '
#                               'spent Thanksgiving in ICE custody far from her '
#                               '11-year-old son.',
#                'id': '357661e68c21bff6e8ecc5b60d39d2bf',
#                'image': 'https://www.thedailybeast.com/resizer/v2/IHXFQO3K6ZHMVFTSN2SZXGKOBA.jpg?smart=true&auth=39bad02046b0ce376e8ae8cc705470ea9ab56114accad01a653496baf3b1bd14&width=1200&height=630',
#                'lang': 'en',
#                'publishedAt': '2025-11-28T15:18:00Z',
#                'source': {'id': 'e3fd974e36370d094fc026102a75c80f',
#                           'name': 'The Daily Beast',
#                           'url': 'https://www.thedailybeast.com'},
#                'title': 'Karoline Leavitt’s Relative Detained by ICE Gets '
#                         'Bittersweet Update',
#                'url': 'https://www.thedailybeast.com/white-house-spokeswoman-karoline-leavitts-brazil-relative-detained-by-dhs-ice-shares-bittersweet-update/'}],
#  'information': {'realTimeArticles': {'message': 'Real-time news data is only '
#                                                  'available on paid plans. '
#                                                  'Free plan has a 12-hour '
#                                                  'delay. Upgrade your plan '
#                                                  'here to remove the delay: '
#                                                  'https://gnews.io/change-plan'}},
#  'totalArticles': 14496}

# %%
len(data["articles"][0]["content"])
# Out:
# 266
