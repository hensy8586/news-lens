# %%
import os
from dotenv import load_dotenv
load_dotenv(".env")
# Out:
# True

# %%
import json
import re
from datetime import datetime, timezone, timedelta
from typing import Any, Dict, List, Tuple, Optional, Set

from supabase import create_client
from openai import OpenAI

from src.prompt_store import get_or_seed_prompt_template, PromptTemplateRow

def utc_now_iso() -> str:
    return datetime.now(timezone.utc).isoformat()

def clip_text(s: str, max_chars: int) -> str:
    return (s or "").strip()[:max_chars]

def normalize_bullets(md: str) -> str:
    if not md:
        return md
    lines = [ln.rstrip() for ln in md.strip().splitlines() if ln.strip()]
    out = []
    for ln in lines:
        s = ln.strip()
        if s.startswith(("-", "•")):
            out.append("- " + s.lstrip("-•").strip())
        elif len(s) >= 3 and s[0].isdigit() and s[1] in (".", "。"):
            out.append("- " + s[2:].strip())
        else:
            out.append(s)
    return "\n".join(out).strip()

def extract_json(txt: str) -> str:
    t = (txt or "").strip()
    t = re.sub(r"^```(?:json)?\s*", "", t, flags=re.IGNORECASE).strip()
    t = re.sub(r"\s*```$", "", t).strip()
    if t.startswith("{") and t.endswith("}"):
        return t
    m = re.search(r"\{.*\}", t, flags=re.DOTALL)
    return m.group(0).strip() if m else ""

def parse_json(txt: str) -> Dict[str, Any]:
    j = extract_json(txt)
    if not j:
        raise ValueError(f"Expected JSON; got:\n{txt[:400]}")
    return json.loads(j)

class SafeDict(dict):
    def __missing__(self, key):
        return ""

def render_template(template: str, variables: Dict[str, Any]) -> str:
    return (template or "").format_map(SafeDict(**variables))

def build_single_prompt(pt: PromptTemplateRow, variables: Dict[str, Any]) -> str:
    user_part = render_template(pt.user_prompt_template, variables)
    if pt.system_prompt and pt.system_prompt.strip():
        sys_part = render_template(pt.system_prompt, variables)
        return f"{sys_part}\n\n{user_part}".strip()
    return user_part.strip()

# %%
import src.prompt_versions as pv
import src.prompt_store as ps

print("prompt_versions file:", pv.__file__)
print("prompt_store file:", ps.__file__)

print(("storyline_digest_en", "v1") in pv.PROMPT_SPECS, "in prompt_versions")
print(("storyline_digest_en", "v1") in ps.PROMPT_SPECS, "in prompt_store")

print("len(prompt_versions.PROMPT_SPECS) =", len(pv.PROMPT_SPECS))
print("len(prompt_store.PROMPT_SPECS)    =", len(ps.PROMPT_SPECS))
# Out:
# prompt_versions file: /Users/hensy/Documents/Repos/news-lens/src/prompt_versions.py
# prompt_store file: /Users/hensy/Documents/Repos/news-lens/src/prompt_store.py
# True in prompt_versions
# True in prompt_store
# len(prompt_versions.PROMPT_SPECS) = 9
# len(prompt_store.PROMPT_SPECS)    = 9

# %%
# Supabase + OpenAI + DeepSeek clients
sb = create_client(os.environ["SUPABASE_URL"], os.environ["SUPABASE_KEY"])
oa = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
ds = OpenAI(
    api_key=os.environ["DEEPSEEK_API_KEY"],
    base_url=os.getenv("DEEPSEEK_BASE_URL", "https://api.deepseek.com"),
)

# Prompt templates (must be seeded in your prompt_store)
pt_summary = get_or_seed_prompt_template(sb, "summary", "v1")
pt_digest_en = get_or_seed_prompt_template(sb, "storyline_digest_en", "v1")
pt_digest_zh = get_or_seed_prompt_template(sb, "storyline_digest_translate_zh", "v1")
pt_polish = get_or_seed_prompt_template(sb, "storyline_title_zh_polish", "v1")  # optional

# %%
LOOKBACK_HOURS = 72
TOP_N = 6
K = 3
MIN_ARTICLES = 2
MIN_SOURCES = 2

MAX_CHARS_FOR_LLM = 12000

def fetch_recent_clustered_articles():
    cutoff = (datetime.now(timezone.utc) - timedelta(hours=LOOKBACK_HOURS)).isoformat()
    res = (
        sb.table("articles")
        .select("id,title,link,source_outlet,published_at,content_text,primary_storyline_id,clustered_at,ai_processed_at,ai_eligible,archived")
        .eq("ai_eligible", True)
        .eq("archived", False)
        .not_.is_("clustered_at", "null")
        .not_.is_("primary_storyline_id", "null")
        .gte("published_at", cutoff)
        .order("published_at", desc=True)
        .limit(5000)
        .execute()
    )
    return res.data or []

def rank_storylines(articles: List[Dict[str, Any]]) -> List[Tuple[str, Dict[str, Any]]]:
    agg: Dict[str, Dict[str, Any]] = {}
    for a in articles:
        sid = a.get("primary_storyline_id")
        if not sid:
            continue
        row = agg.setdefault(sid, {"count": 0, "sources": set(), "latest": None})
        row["count"] += 1
        src = a.get("source_outlet") or ""
        if src:
            row["sources"].add(src)
        pub = a.get("published_at")
        if pub and (row["latest"] is None or pub > row["latest"]):
            row["latest"] = pub

    ranked = []
    for sid, st in agg.items():
        st["source_count"] = len(st["sources"])
        if st["count"] >= MIN_ARTICLES and st["source_count"] >= MIN_SOURCES:
            ranked.append((sid, st))

    ranked.sort(key=lambda x: (x[1]["count"], x[1]["source_count"], x[1]["latest"] or ""), reverse=True)
    return ranked

def fetch_articles_for_storyline(storyline_id: str) -> List[Dict[str, Any]]:
    cutoff = (datetime.now(timezone.utc) - timedelta(hours=LOOKBACK_HOURS)).isoformat()
    res = (
        sb.table("articles")
        .select("id,title,link,source_outlet,published_at,content_text,ai_processed_at")
        .eq("primary_storyline_id", storyline_id)
        .eq("ai_eligible", True)
        .eq("archived", False)
        .not_.is_("published_at", "null")  # optional safety
        .gte("published_at", cutoff)
        .order("published_at", desc=True)
        .limit(200)
        .execute()
    )
    return res.data or []


def pick_representative_articles(candidates: List[Dict[str, Any]], k: int) -> List[Dict[str, Any]]:
    candidates = sorted(candidates, key=lambda a: a.get("published_at") or "", reverse=True)

    chosen: List[Dict[str, Any]] = []
    used_sources: Set[str] = set()

    # pass 1: unprocessed + distinct sources
    for a in candidates:
        if len(chosen) >= k:
            break
        if a.get("ai_processed_at") is not None:
            continue
        src = a.get("source_outlet") or ""
        if src and src in used_sources:
            continue
        chosen.append(a)
        if src:
            used_sources.add(src)

    # pass 2: fill remaining with unprocessed (allow repeats)
    if len(chosen) < k:
        for a in candidates:
            if len(chosen) >= k:
                break
            if a.get("ai_processed_at") is not None:
                continue
            if a["id"] in {x["id"] for x in chosen}:
                continue
            chosen.append(a)

    # pass 3: allow already-processed
    if len(chosen) < k:
        for a in candidates:
            if len(chosen) >= k:
                break
            if a["id"] in {x["id"] for x in chosen}:
                continue
            chosen.append(a)

    return chosen

# %%
def run_openai_text(pt: PromptTemplateRow, variables: Dict[str, Any]) -> str:
    prompt = build_single_prompt(pt, variables)
    resp = oa.responses.create(
        model=pt.model_name,
        input=prompt,
        temperature=float(pt.temperature or 0.0),
        max_output_tokens=pt.max_output_tokens,
    )
    return (resp.output_text or "").strip()

def run_deepseek_text(pt: PromptTemplateRow, variables: Dict[str, Any]) -> str:
    # DeepSeek uses chat.completions in your codebase
    messages = []
    if pt.system_prompt and pt.system_prompt.strip():
        messages.append({"role": "system", "content": render_template(pt.system_prompt, variables)})
    messages.append({"role": "user", "content": render_template(pt.user_prompt_template, variables)})

    resp = ds.chat.completions.create(
        model=os.getenv("DEEPSEEK_MODEL", "deepseek-chat"),
        messages=messages,
        temperature=float(pt.temperature or 0.0),
        max_tokens=int(pt.max_output_tokens or 800),
    )
    return (resp.choices[0].message.content or "").strip()

def summarize_article_en(title: str, content_text: str) -> str:
    out = run_openai_text(pt_summary, {
        "title": title,
        "content": clip_text(content_text, MAX_CHARS_FOR_LLM),
    })
    return normalize_bullets(out)

def build_digest_input_en(reps: List[Dict[str, Any]], per_article_en: Dict[str, str]) -> str:
    blocks = []
    for a in reps:
        aid = a["id"]
        summ = per_article_en.get(aid, "").strip()
        if not summ:
            continue
        src = a.get("source_outlet") or ""
        title = a.get("title") or ""
        blocks.append(f"Outlet: {src}\nTitle: {title}\nSummary:\n{summ}".strip())
    return "\n\n---\n\n".join(blocks).strip()

def digest_storyline_en(digest_input: str, article_count: int, source_count: int) -> Dict[str, str]:
    out = run_openai_text(pt_digest_en, {
        "digest_input": digest_input,
        "article_count": article_count,
        "source_count": source_count,
    })
    obj = parse_json(out)
    return {"title_en": obj.get("title_en","").strip(), "summary_en": obj.get("summary_en","").strip()}

def translate_digest_zh(title_en: str, summary_en: str) -> Dict[str, str]:
    out = run_deepseek_text(pt_digest_zh, {
        "title_en": title_en,
        "summary_en": summary_en,
    })
    obj = parse_json(out)
    return {"title_zh": obj.get("title_zh","").strip(), "summary_zh": obj.get("summary_zh","").strip()}

def polish_title_zh(title_zh: str) -> str:
    if not title_zh.strip():
        return title_zh
    out = run_openai_text(pt_polish, {"title_zh": title_zh})
    return out.strip() or title_zh

# %%
# Controls
DRY_RUN_ONLY = True  # keep True for notebook testing
STORYLINE_INDEX = 0  # choose which top storyline to preview

recent = fetch_recent_clustered_articles()
ranked = rank_storylines(recent)

print(f"Found {len(ranked)} eligible storylines in last {LOOKBACK_HOURS}h.")
for i, (sid, st) in enumerate(ranked[:10]):
    print(i, sid, "count=", st["count"], "sources=", st["source_count"], "latest=", st["latest"])

# storyline_id, stats = ranked[STORYLINE_INDEX]

for i, (storyline_id, stats) in enumerate(ranked[:TOP_N]):
    print(f"\n=== STORYLINE {i+1} ===")
    print("Articles:", stats["count"], "Sources:", stats["source_count"])

    candidates = fetch_articles_for_storyline(storyline_id)
    reps = pick_representative_articles(candidates, k=K)

    print("\nSelected representative articles:")
    for a in reps:
        print("-", a.get("source_outlet"), "|", (a.get("title") or "")[:90])

    # 1) summarize reps in EN (only for testing)
    per_article_en = {}
    for a in reps:
        title = a.get("title") or ""
        content = a.get("content_text") or ""
        if not content.strip():
            continue
        per_article_en[a["id"]] = summarize_article_en(title, content)

    digest_input = build_digest_input_en(reps, per_article_en)
    print("\nDigest input length:", len(digest_input))

    # 2) English storyline digest
    dig_en = digest_storyline_en(digest_input, article_count=stats["count"], source_count=stats["source_count"])

    # 3) translate digest -> zh
    dig_zh = translate_digest_zh(dig_en["title_en"], dig_en["summary_en"])

    # 4) optional polish
    dig_zh["title_zh"] = polish_title_zh(dig_zh["title_zh"])

    # ---- Publishable output ----
    print("\n====================")
    print("ENGLISH (publishable)")
    print("====================")
    print(dig_en["title_en"])
    print(dig_en["summary_en"])

    print("\n====================")
    print("中文（可发布）")
    print("====================")
    print(f"【{dig_zh['title_zh']}】")
    print(dig_zh["summary_zh"])
    print("\n\n")
# Out:
# Found 16 eligible storylines in last 72h.
# 0 55887cd9-e6e8-430b-8856-aae9c5d52960 count= 34 sources= 5 latest= 2026-01-19T18:12:19+00:00
# 1 2788d85a-2c50-4bbd-949b-8a3ae10161fb count= 23 sources= 6 latest= 2026-01-19T18:27:54+00:00
# 2 3497fc1d-2a4d-44a1-908c-3cc77d17c96f count= 15 sources= 4 latest= 2026-01-19T17:29:17+00:00
# 3 fd4ae98e-34a8-4a8a-b8bd-225017ab046b count= 6 sources= 2 latest= 2026-01-19T16:38:16+00:00
# 4 c4f91884-e2dc-4c7d-a7a3-bcb061bc5c74 count= 4 sources= 3 latest= 2026-01-19T12:12:38+00:00
# 5 c6d2f4fb-2a3d-4370-9e98-8e3a5aa0cfbc count= 4 sources= 2 latest= 2026-01-19T09:38:09+00:00
# 6 60b757fb-8921-45f1-b225-6a79a44343ad count= 3 sources= 2 latest= 2026-01-19T18:00:00+00:00
# 7 8910b744-8d3d-419a-a69f-6f377a121f6e count= 3 sources= 2 latest= 2026-01-19T17:32:30+00:00
# 8 8baccaaa-1f3b-475d-b70c-6fa0a158ae22 count= 3 sources= 2 latest= 2026-01-19T08:52:15+00:00
# 9 c7a210e5-c4ca-4073-bd7d-aa5bc592e0ee count= 3 sources= 2 latest= 2026-01-19T05:00:16+00:00
#
# === STORYLINE 1 ===
# Articles: 34 Sources: 5
#
# Selected representative articles:
# - The Guardian US News | What are Trump’s latest tariff threats and could the EU hit back with its ‘big bazooka’?
# - The Guardian World News | Trump says ‘no comment’ when asked if he would seize Greenland by force – Europe live
# - BBC Main Headlines | Gold and silver prices hit high after tariff threat
# - The Guardian Europe News | Starmer calls for ‘calm discussion’ on Greenland and plays down chance of retaliatory tari
# - BBC World | What tariffs has Trump announced and why?
#
# Digest input length: 3261
#
# ====================
# ENGLISH (publishable)
# ====================
# Trump Threatens Tariffs on Europe Over Greenland Dispute Amid Trade Tensions
# - President Trump threatened punitive tariffs on imports from eight European countries starting February 1, with rates rising to 25% by June, in response to opposition over his Greenland ambitions.
# - The tariff threats have raised concerns about a potential transatlantic trade war, with European stock markets falling and precious metals like gold and silver hitting high prices.
# - Some reports indicate Trump declined to rule out using force to seize Greenland and expressed frustration with European leaders' focus on Greenland rather than the Russia-Ukraine conflict.
# - European officials may consider retaliatory measures using powerful but untested trade laws, though some political leaders have called for calm and pragmatic discussions to avoid escalation.
# - The tariffs are part of a broader US strategy that includes previous tariffs on China, Canada, Mexico, India, Brazil, and South Africa aimed at boosting US manufacturing and reducing trade deficits.
# - The IMF has warned that escalating trade tensions pose a significant risk to global economic growth, forecasting slower growth worldwide in the coming years.
# - The US Supreme Court is expected to rule soon on the legality of some tariffs imposed under emergency powers, adding uncertainty to the trade dispute.
#
# ====================
# 中文（可发布）
# ====================
# 【特朗普因格陵兰争端威胁对欧加征关税 跨大西洋贸易紧张升级】
# - 特朗普总统威胁自2月1日起对八个欧洲国家进口商品加征惩罚性关税，税率将在6月前升至25%，以回应欧洲对其格陵兰计划的反对。
# - 关税威胁引发对跨大西洋贸易战的担忧，欧洲股市下跌，黄金和白银等贵金属价格升至高位。
# - 有报道称，特朗普未排除使用武力夺取格陵兰的可能性，并对欧洲领导人关注格陵兰而非俄乌冲突表示不满。
# - 欧洲官员可能考虑动用强大但未经检验的贸易法进行反制，部分政治领导人则呼吁保持冷静并进行务实讨论以避免局势升级。
# - 此次关税是美国更广泛战略的一部分，此前已对中国、加拿大、墨西哥、印度、巴西和南非加征关税，旨在提振美国制造业并减少贸易逆差。
# - 国际货币基金组织警告称，不断升级的贸易紧张局势对全球经济增长构成重大风险，并预测未来几年全球增长将放缓。
# - 美国最高法院预计将很快对依据紧急权力征收的部分关税的合法性作出裁决，为贸易争端增添了不确定性。
#
#
#
#
# === STORYLINE 2 ===
# Articles: 23 Sources: 6
#
# Selected representative articles:
# - The Guardian US News | Donald Trump needs helpers for his appalling neocolonialist project. What else is this ‘bo
# - BBC World | 'Europe is at a total loss': Russia gloats over Greenland tensions
# - The Guardian Europe News | Kremlin says Putin has been invited to join Trump’s Gaza ‘board of peace’
# - NPR | Trump says he's pursuing Greenland after perceived Nobel Peace Prize snub
# - The Guardian World News | ‘I was afraid for my life’: the transgender refugees fleeing Trump’s America
#
# Digest input length: 3911
#
# ====================
# ENGLISH (publishable)
# ====================
# Trump's Gaza Board, Greenland Pursuit, and Trans Refugee Crisis Highlight Global Tensions
# - Donald Trump announced a "board of peace" to govern Gaza without Palestinian representation, including figures like Tony Blair, Jared Kushner, and reportedly Vladimir Putin, requiring $1 billion from countries for permanent membership.
# - The board aims to bypass the UN and involves plans for Gaza population resettlement and luxury development amid ongoing Israeli military actions.
# - Russia confirmed receiving an invitation for Putin to join the Gaza board and is reviewing details, while France declined participation citing UN commitments.
# - Trump linked his pursuit of Greenland to a perceived Nobel Peace Prize snub, demanding "complete and total control" of the island and imposing tariffs on Denmark, which has sovereignty over Greenland.
# - Russia praised the Greenland tensions as weakening the US-EU alliance, viewing good ties with Trump as beneficial for its Ukraine war efforts.
# - The Netherlands is seeing a rise in transgender American asylum seekers fleeing perceived hostility and violence under Trump-era policies, though asylum claims remain difficult to win and deportations continue.
# - Trans refugees express fears of detention, harm, or forced detransition if returned to the US due to restricted healthcare and discrimination.
#
# ====================
# 中文（可发布）
# ====================
# 【特朗普组建加沙治理委员会引争议，格陵兰主权与跨性别难民问题加剧国际紧张】
# - 特朗普宣布组建无巴勒斯坦代表的加沙“和平委员会”，成员包括托尼·布莱尔、贾里德·库什纳等，有报道称普京亦获邀，常任理事国需支付10亿美元。
# - 该委员会旨在绕过联合国，计划在以色列军事行动持续背景下进行加沙人口重新安置及豪华地产开发。
# - 俄罗斯确认收到普京加入该委员会的邀请并正在审议细节，法国则以遵守联合国框架为由拒绝参与。
# - 特朗普将追求格陵兰岛控制权与未获诺贝尔和平奖相关联，要求对该岛拥有“完全控制权”并对主权国丹麦加征关税。
# - 俄罗斯称赞格陵兰岛争端削弱了美欧联盟，认为与特朗普保持良好关系有利于其在乌克兰的军事行动。
# - 荷兰出现逃离特朗普时期政策的美国跨性别寻求庇护者潮，他们担忧回国后面临敌意、暴力、拘留或被迫终止性别确认医疗。
# - 尽管庇护申请难以获批且遣返持续进行，这些难民仍因美国医疗限制与歧视风险而选择出走。
#
#
#
#
# === STORYLINE 3 ===
# Articles: 15 Sources: 4
#
# Selected representative articles:
# - The Guardian Europe News | ‘We had to remove the dead to get to the living’: train crash shocks Spanish town
# - BBC World | What we know about Spain's worst rail disaster in over a decade
# - The Guardian World News | Spain train crash: rescue efforts continue as death toll rises in Córdoba crash – latest u
# - NPR | At least 39 dead in Spain train collision as rescuers search for more bodies
# - The Guardian Europe News | Spain train crash: drivers had raised concerns over track before collision that killed 39
#
# Digest input length: 3805
#
# ====================
# ENGLISH (publishable)
# ====================
# Spain Train Collision Near Córdoba Kills 39, Dozens Injured
# - At least 39 people died and dozens were injured after two trains collided near Adamuz, Córdoba, Spain, on Sunday evening.
# - The crash involved a high-speed Iryo train from Málaga to Madrid derailing and hitting a Renfe train traveling from Madrid to Huelva.
# - Rescue efforts faced challenges due to twisted metal and trapped victims; about 122 people received medical aid, with 48 hospitalized including minors and 12 in intensive care.
# - The cause of the accident remains unknown, with investigations expected to take about a month; mechanical faults, infrastructure issues, or track problems are being considered.
# - Train drivers' union SEMAF had previously warned the rail infrastructure administrator ADIF about track issues, including potholes and power line imbalances, but no response has been reported.
# - The derailed train was relatively new, operated by the private company Iryo, making the accident unusual.
# - The local community in Adamuz, a town of 4,000, mobilized to support victims and emergency services, turning the municipal hall into an emergency center and providing aid to passengers and families.
#
# ====================
# 中文（可发布）
# ====================
# 【西班牙科尔多瓦列车相撞致39死数十伤】
# - 周日傍晚，西班牙科尔多瓦附近阿达穆兹发生两列火车相撞事故，造成至少39人死亡，数十人受伤。
# - 事故涉及一列从马拉加开往马德里的高速Iryo列车脱轨，并与一列从马德里开往韦尔瓦的Renfe列车相撞。
# - 救援工作因金属扭曲和被困乘客而面临挑战；约122人接受了医疗救助，其中48人住院，包括未成年人，12人进入重症监护室。
# - 事故原因尚不明确，调查预计将持续约一个月；机械故障、基础设施问题或轨道问题均在考虑之列。
# - 有报道称，火车司机工会SEMAF此前曾就轨道问题（包括坑洼和电力线不平衡）向铁路基础设施管理机构ADIF发出警告，但未获回应。
# - 脱轨的Iryo列车相对较新，由私营公司运营，使得此次事故显得不同寻常。
# - 拥有约4000人口的阿达穆兹当地社区动员起来支持受害者和应急服务，将市政厅改为应急中心，并为乘客和家属提供援助。
#
#
#
#
# === STORYLINE 4 ===
# Articles: 6 Sources: 2
#
# Selected representative articles:
# - BBC Main Headlines | Senegal reserve keeper jokes after Afcon towel scuffles
# - BBC World | Ecstasy and now a day off - Senegal fans around the world celebrate Afcon win
# - BBC Main Headlines | Is a Panenka ever the right choice for a penalty?
# - BBC World | 'Shameful' and 'terrible look' - the chaos that marred Senegal's Afcon triumph
# - BBC Main Headlines | Diaz will 'have nightmares' over 'Panenka' failure
#
# Digest input length: 3844
#
# ====================
# ENGLISH (publishable)
# ====================
# Senegal Wins Chaotic Afcon Final After Missed Penalty and Extra-Time Goal
# - Senegal defeated Morocco 1-0 in the 2025 Africa Cup of Nations final in Rabat, with Pape Gueye scoring the winning goal in extra time.
# - The match was marked by controversy, including a stoppage-time penalty awarded to Morocco, which was saved by Senegal goalkeeper Edouard Mendy.
# - Senegal players temporarily left the field in protest after the penalty decision, causing a 17-minute delay.
# - Morocco captain Achraf Hakimi and others were involved in incidents attempting to remove Senegal's towels, leading to criticism and condemnation from FIFA president Gianni Infantino.
# - Senegal's reserve goalkeeper Yehvann Diouf humorously defended the team's towels amid scuffles with ball boys.
# - Brahim Diaz missed a crucial Panenka penalty for Morocco, which was saved by Mendy, contributing to Senegal's victory.
# - Senegal's President declared a public holiday to celebrate the win, with fans worldwide expressing joy, while Morocco plans legal action over the match disruptions.
#
# ====================
# 中文（可发布）
# ====================
# 【塞内加尔加时绝杀摩洛哥夺2025非洲杯冠军】
# - 在拉巴特举行的2025非洲杯决赛中，塞内加尔凭借帕普·盖伊加时赛的进球，以1比0战胜摩洛哥。
# - 比赛充满争议，摩洛哥在补时阶段获得点球，但被塞内加尔门将爱德华·门迪扑出。
# - 点球判罚后，塞内加尔球员一度离场抗议，导致比赛中断约17分钟。
# - 有报道称，摩洛哥队长阿什拉夫·哈基米等人卷入试图移除塞内加尔毛巾的事件，国际足联主席因凡蒂诺对此提出批评。
# - 摩洛哥球员布拉欣·迪亚兹主罚的“勺子点球”被门迪扑出，错失关键机会。
# - 塞内加尔总统宣布全国放假庆祝胜利，摩洛哥方面则计划就比赛中断采取法律行动。
#
#
#
#
# === STORYLINE 5 ===
# Articles: 4 Sources: 3
#
# Selected representative articles:
# - The Guardian World News | China’s population falls again as birthrate drops 17% to record low
# - BBC World | China's birth rate hits record low as population continues to shrink
# - BBC Main Headlines | China hits growth goal after exports boom defied US tariffs
# - The Guardian World News | China’s economy hit growth target last year despite Trump trade war and property crisis
#
# Digest input length: 2830
#
# ====================
# ENGLISH (publishable)
# ====================
# China’s Population Declines Amid Record Low Birthrate and Economic Challenges
# - China’s population fell by approximately 3.39 million to around 1.4 billion in 2025, marking the fourth consecutive annual decline.
# - The birthrate dropped sharply to a record low, with births falling 17% to about 7.9 million, the lowest since 1949.
# - Deaths increased to over 11 million, the highest since 1968, contributing to the population decrease.
# - The government has introduced incentives including childcare subsidies totaling 90 billion yuan and direct payments to parents, alongside easing marriage restrictions.
# - Economic growth reached 5% in 2025, meeting official targets despite slowing to 4.5% in the fourth quarter and ongoing domestic challenges.
# - China recorded a record trade surplus exceeding $1.1 trillion, driven by strong exports outside the US amid trade tensions.
# - The property market remains weak, with significant price declines and investment drops, raising concerns about debt and consumer confidence.
#
# ====================
# 中文（可发布）
# ====================
# 【中国人口四年连降，出生率创新低，经济增长与挑战并存】
# - 2025年中国人口连续第四年下降，减少约339万人，总人口降至约14亿。
# - 出生率降至历史新低，新生儿数量下降17%至约790万，为1949年以来最低。
# - 死亡人数上升至超过1100万，为1968年以来最高，加剧了人口负增长。
# - 政府推出包括900亿元育儿补贴、直接支付给父母以及放宽婚姻限制在内的激励措施。
# - 2025年经济增长率达到5%，符合官方目标，但第四季度放缓至4.5%，国内挑战持续。
# - 在贸易紧张局势下，对非美地区出口强劲，推动中国录得超过1.1万亿美元的创纪录贸易顺差。
# - 房地产市场持续疲软，价格与投资显著下滑，引发对债务和消费者信心的担忧。
#
#
#
#
# === STORYLINE 6 ===
# Articles: 4 Sources: 2
#
# Selected representative articles:
# - BBC World | Man seriously injured in Sydney's third shark attack in two days
# - The Guardian World News | Man in critical condition after third Sydney shark attack in two days
# - The Guardian World News | Sydney Harbour shark attack: second incident in two days as police warn against swimming
# - The Guardian World News | Sydney Harbour shark attack: police warn against swimming and say heavy rain created ‘perf
#
# Digest input length: 3031
#
# ====================
# ENGLISH (publishable)
# ====================
# Three Shark Attacks in Sydney Over Two Days Leave Multiple Injured
# - Three shark attacks occurred on Sydney beaches within two days, resulting in at least two people critically injured.
# - A man in his 20s was critically injured at Manly Beach on Monday evening and hospitalized.
# - A 12-year-old boy was critically injured by a likely bull shark near Nielsen Park in Sydney Harbour on Sunday, sustaining serious leg injuries.
# - An 11-year-old surfer was bitten on his board at Dee Why Beach on Monday but was unharmed.
# - Authorities closed Northern Beaches and other nearby areas following the attacks and advised against swimming in murky, brackish water.
# - Heavy rainfall and resulting poor water visibility are believed to have increased shark activity, with bull sharks suspected in the incidents.
# - Emergency responders and bystanders provided immediate aid to victims, including tourniquets and CPR before hospital transport.
#
# ====================
# 中文（可发布）
# ====================
# 【悉尼两天内三起鲨鱼袭击致多人受伤】
# - 悉尼海滩两日内发生三起鲨鱼袭击事件，至少两人伤势危重。
# - 一名20多岁男子周一晚间在曼利海滩遭袭，伤势危重送医。
# - 一名12岁男孩周日在悉尼港尼尔森公园附近遭疑似公牛鲨袭击，腿部严重受伤。
# - 另有一名11岁冲浪者周一在迪怀海滩被咬到冲浪板，本人未受伤。
# - 事发后当局关闭北部海滩等区域，并建议民众勿在浑浊的咸淡水中游泳。
# - 据信强降雨导致水体能见度降低，增加了鲨鱼活动，事件中疑为公牛鲨所为。
# - 紧急救援人员及旁观者在伤者送医前提供了止血带及心肺复苏等急救措施。

# %%
lines = []
lines.append(f"【{dig_zh['title_zh']}】")
lines.append(dig_zh["summary_zh"])
lines.append("")
lines.append("—— 参考报道 ——")
for a in reps:
    src = a.get("source_outlet") or ""
    title = a.get("title") or ""
    link = a.get("link") or ""
    lines.append(f"- {src}｜{title}\n  {link}")

post_zh = "\n".join(lines).strip()
print(post_zh)
# Out:
# 【特朗普因格陵兰争端威胁对欧加征关税 欧盟拟法律反制】
# - 美国总统特朗普威胁自2月1日起，对包括丹麦、挪威、瑞典、法国、德国、英国、荷兰和芬兰在内的八个欧洲国家进口商品加征10%关税，此举与格陵兰争端有关。
# - 特朗普在被问及是否可能动用武力获取格陵兰时，以“不予置评”回应，未排除使用武力的可能性。
# - 关税威胁引发对跨大西洋贸易战的担忧，欧洲股市应声下跌，金银价格则攀升至多年高位。
# - 欧盟正考虑一项被称为“大型火箭筒”的强力法律反制措施，可能对价值约930亿欧元的美国进口商品加征报复性关税。
# - 此次争端凸显了美欧之间围绕格陵兰战略重要性及更广泛地缘政治问题的紧张关系。
# - 市场波动还受到对降息的预期以及中国出口限制等其他因素的影响。
# - 美国最高法院预计将很快对特朗普依据紧急权力实施的关税合法性作出裁决。
#
# —— 参考报道 ——
# - The Guardian US News｜What are Trump’s latest tariff threats and could the EU hit back with its ‘big bazooka’?
#   https://www.theguardian.com/us-news/2026/jan/19/donald-trump-tariff-eu-aci-europe-greenland-trade-war
# - The Guardian World News｜Trump says ‘no comment’ when asked if he would seize Greenland by force – Europe live
#   https://www.theguardian.com/world/live/2026/jan/19/donald-trump-greenland-denmark-nobel-nato-europe-live-latest-news-updates
# - BBC Main Headlines｜Gold and silver prices hit high after tariff threat
#   https://www.bbc.com/news/articles/cx2yppj4lg4o?at_medium=RSS&at_campaign=rss
